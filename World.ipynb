# %% [markdown]
# <h2>World Counteries</h2>

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
def file(filename):
    with open(filename) as f:
     fil = json.load(f)
     return fil

# %%
df = pd.read_csv('countries-indicators.csv')
df.head()
# Out:
#   Country Name Country Code              Series Name     Series Code  \
# 0  Afghanistan          AFG  GDP (constant 2015 US$)  NY.GDP.MKTP.KD
# 1  Afghanistan          AFG       Land area (sq. km)  AG.LND.TOTL.K2
# 2  Afghanistan          AFG        Population, total     SP.POP.TOTL
# 3      Albania          ALB  GDP (constant 2015 US$)  NY.GDP.MKTP.KD
# 4      Albania          ALB       Land area (sq. km)  AG.LND.TOTL.K2
#
#   1973 [YR1973] 1974 [YR1974] 1975 [YR1975] 1976 [YR1976] 1977 [YR1977]  \
# 0            ..            ..            ..            ..            ..
# 1        652230        652230        652230        652230        652230
# 2      11575305      11869879      12157386      12425267      12687301
# 3            ..            ..            ..            ..            ..
# 4         27400         27400         27400         27400         27400
#
#   1978 [YR1978]  ... 2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 54 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   653 non-null    object
#  1   Country Code   651 non-null    object
#  2   Series Name    651 non-null    object
#  3   Series Code    651 non-null    object
#  4   1973 [YR1973]  651 non-null    object
#  5   1974 [YR1974]  651 non-null    object
#  6   1975 [YR1975]  651 non-null    object
#  7   1976 [YR1976]  651 non-null    object
#  8   1977 [YR1977]  651 non-null    object
#  9   1978 [YR1978]  651 non-null    object
#  10  1979 [YR1979]  651 non-null    object
#  11  1980 [YR1980]  651 non-null    object
#  12  1981 [YR1981]  651 non-null    object
#  13  1982 [YR1982]  651 non-null    object
#  14  1983 [YR1983]  651 non-null    object
#  15  1984 [YR1984]  651 non-null    object
#  16  1985 [YR1985]  651 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Country Name     3
# Country Code     5
# Series Name      5
# Series Code      5
# 1973 [YR1973]    5
# 1974 [YR1974]    5
# 1975 [YR1975]    5
# 1976 [YR1976]    5
# 1977 [YR1977]    5
# 1978 [YR1978]    5
# 1979 [YR1979]    5
# 1980 [YR1980]    5
# 1981 [YR1981]    5
# 1982 [YR1982]    5
# 1983 [YR1983]    5
# 1984 [YR1984]    5
# 1985 [YR1985]    5
# 1986 [YR1986]    5
# 1987 [YR1987]    5
# 1988 [YR1988]    5
# 1989 [YR1989]    5
# 1990 [YR1990]    5
# 1991 [YR1991]    5
# 1992 [YR1992]    5
# 1993 [YR1993]    5
# 1994 [YR1994]    5
# 1995 [YR1995]    5
# 1996 [YR1996]    5
# 1997 [YR1997]    5
# 1998 [YR1998]    5
# 1999 [YR1999]    5
# 2000 [YR2000]    5
# 2001 [YR2001]    5
# 2002 [YR2002]    5
# 2003 [YR2003]    5
# 2004 [YR2004]    5
# 2005 [YR2005]    5
# 2006 [YR2006]    5
# 2007 [YR2007]    5
# 2008 [YR2008]    5
# 2009 [YR2009]    5
# 2010 [YR2010]    5
# 2011 [YR2011]    5
# 2012 [YR2012]    5
# 2013 [YR2013]    5
# 2014 [YR2014]    5
# 2015 [YR2015]    5
# ...

# %%
df.dropna()
# Out:
#     Country Name Country Code              Series Name     Series Code  \
# 0    Afghanistan          AFG  GDP (constant 2015 US$)  NY.GDP.MKTP.KD
# 1    Afghanistan          AFG       Land area (sq. km)  AG.LND.TOTL.K2
# 2    Afghanistan          AFG        Population, total     SP.POP.TOTL
# 3        Albania          ALB  GDP (constant 2015 US$)  NY.GDP.MKTP.KD
# 4        Albania          ALB       Land area (sq. km)  AG.LND.TOTL.K2
# ..           ...          ...                      ...             ...
# 646       Zambia          ZMB       Land area (sq. km)  AG.LND.TOTL.K2
# 647       Zambia          ZMB        Population, total     SP.POP.TOTL
# 648     Zimbabwe          ZWE  GDP (constant 2015 US$)  NY.GDP.MKTP.KD
# 649     Zimbabwe          ZWE       Land area (sq. km)  AG.LND.TOTL.K2
# 650     Zimbabwe          ZWE        Population, total     SP.POP.TOTL
#
#     1973 [YR1973] 1974 [YR1974] 1975 [YR1975] 1976 [YR1976] 1977 [YR1977]  \
# ...

# %%
df['1973 [YR1973]']  = df['1973 [YR1973]'].str.replace('..', '')

# %%
df['1973 [YR1973]'] = df['1973 [YR1973]'].str.replace('...', '')

# %%
df['1973 [YR1973]']
# Out:
# 0
# 1        652230
# 2      11575305
# 3
# 4         27400
#          ...
# 651         NaN
# 652         NaN
# 653         NaN
# 654         NaN
# 655         NaN
# Name: 1973 [YR1973], Length: 656, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 54 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   653 non-null    object
#  1   Country Code   651 non-null    object
#  2   Series Name    651 non-null    object
#  3   Series Code    651 non-null    object
#  4   1973 [YR1973]  651 non-null    object
#  5   1974 [YR1974]  651 non-null    object
#  6   1975 [YR1975]  651 non-null    object
#  7   1976 [YR1976]  651 non-null    object
#  8   1977 [YR1977]  651 non-null    object
#  9   1978 [YR1978]  651 non-null    object
#  10  1979 [YR1979]  651 non-null    object
#  11  1980 [YR1980]  651 non-null    object
#  12  1981 [YR1981]  651 non-null    object
#  13  1982 [YR1982]  651 non-null    object
#  14  1983 [YR1983]  651 non-null    object
#  15  1984 [YR1984]  651 non-null    object
#  16  1985 [YR1985]  651 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Country Name     3
# Country Code     5
# Series Name      5
# Series Code      5
# 1973 [YR1973]    5
# 1974 [YR1974]    5
# 1975 [YR1975]    5
# 1976 [YR1976]    5
# 1977 [YR1977]    5
# 1978 [YR1978]    5
# 1979 [YR1979]    5
# 1980 [YR1980]    5
# 1981 [YR1981]    5
# 1982 [YR1982]    5
# 1983 [YR1983]    5
# 1984 [YR1984]    5
# 1985 [YR1985]    5
# 1986 [YR1986]    5
# 1987 [YR1987]    5
# 1988 [YR1988]    5
# 1989 [YR1989]    5
# 1990 [YR1990]    5
# 1991 [YR1991]    5
# 1992 [YR1992]    5
# 1993 [YR1993]    5
# 1994 [YR1994]    5
# 1995 [YR1995]    5
# 1996 [YR1996]    5
# 1997 [YR1997]    5
# 1998 [YR1998]    5
# 1999 [YR1999]    5
# 2000 [YR2000]    5
# 2001 [YR2001]    5
# 2002 [YR2002]    5
# 2003 [YR2003]    5
# 2004 [YR2004]    5
# 2005 [YR2005]    5
# 2006 [YR2006]    5
# 2007 [YR2007]    5
# 2008 [YR2008]    5
# 2009 [YR2009]    5
# 2010 [YR2010]    5
# 2011 [YR2011]    5
# 2012 [YR2012]    5
# 2013 [YR2013]    5
# 2014 [YR2014]    5
# 2015 [YR2015]    5
# ...
